# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from tensorflow import keras

# %% [markdown]
# # Load Dataset

# %%
dataset = pd.read_csv('data\weather_dataset.csv', index_col='date', parse_dates=True)

# %%
dataset.head()
# Out:
#              Ttb    Tx    Tn    R   Utb    Un
# date
# 2015-01-01  14.7  25.3   9.3  NaN  75.0  33.0
# 2015-01-02  13.9  23.5   7.5  NaN  75.8  37.0
# 2015-01-03  14.1  21.0   9.5  NaN  83.5  54.0
# 2015-01-04  16.5  18.8  14.6  NaN  88.3  83.0
# 2015-01-05  19.0  22.6  16.5  0.0  87.0  72.0

# %%
dataset.tail()
# Out:
#              Ttb    Tx    Tn   R   Utb    Un
# date
# 2020-12-27  20.3  24.8  17.3 NaN  83.0  67.0
# 2020-12-28  20.7  23.6  18.8 NaN  88.0  77.0
# 2020-12-29  21.4  25.8  19.9 NaN  86.0  74.0
# 2020-12-30  17.5  20.9  16.2 NaN  50.0  42.0
# 2020-12-31  13.6  19.0  12.1 NaN  57.0  41.0

# %% [markdown]
# # Data Preprocessing

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2192 entries, 2015-01-01 to 2020-12-31
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Ttb     2192 non-null   float64
#  1   Tx      2192 non-null   float64
#  2   Tn      2192 non-null   float64
#  3   R       988 non-null    float64
#  4   Utb     2192 non-null   float64
#  5   Un      2192 non-null   float64
# dtypes: float64(6)
# memory usage: 119.9 KB

# %% [markdown]
# ### Chuyển cột mưa (R) về 0 với 1

# %%
dataset = dataset.fillna(-1)

# %%
#labling rain column
for i in range(len(dataset)):
    if  dataset['R'][i] == -1:
        dataset['R'][i] = 0
    else:
        dataset['R'][i] = 1
dataset.head()
# Out:
#              Ttb    Tx    Tn    R   Utb    Un
# date
# 2015-01-01  14.7  25.3   9.3  0.0  75.0  33.0
# 2015-01-02  13.9  23.5   7.5  0.0  75.8  37.0
# 2015-01-03  14.1  21.0   9.5  0.0  83.5  54.0
# 2015-01-04  16.5  18.8  14.6  0.0  88.3  83.0
# 2015-01-05  19.0  22.6  16.5  1.0  87.0  72.0

# %%
dataset.describe()
# Out:
#                Ttb           Tx           Tn           R          Utb  \
# count  2192.000000  2192.000000  2192.000000  2192.00000  2192.000000
# mean     23.350228    28.020073    20.466834     0.45073    83.805246
# std       5.042623     5.702109     4.949226     0.49768     6.906062
# min       6.100000     8.000000     2.500000     0.00000    50.000000
# 25%      19.600000    24.000000    17.100000     0.00000    80.000000
# 50%      24.500000    29.000000    21.600000     0.00000    84.000000
# 75%      27.500000    32.800000    24.600000     1.00000    89.000000
# max      31.500000    39.000000    28.200000     1.00000    99.000000
#
#                 Un
# count  2192.000000
# mean     67.428832
# std      13.725397
# min      23.000000
# 25%      59.000000
# 50%      67.000000
# 75%      77.000000
# max      98.000000

# %%
#dataset.drop('R', axis=1, inplace=True)
#dataset.head()

# %% [markdown]
# ### Scaling dataset

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()
dataset_scaled = scaler.fit_transform(dataset)

# %%
len(dataset_scaled)
# Out:
# 2192

# %% [markdown]
# # Splitting Dataset

# %%
from keras.preprocessing.sequence import TimeseriesGenerator

# %%
rate = 0.2
X, y = dataset_scaled[:-1], dataset_scaled[1:]
pos_split = int(len(X)*(1 - rate))
X_train, X_test, y_train, y_test = X[:pos_split], X[pos_split:], y[:pos_split], y[pos_split:]
X_train[0].shape
# Out:
# (6,)

# %%
from keras.models import Sequential
from keras.layers import Dense

# %%
n_features = 6
model = Sequential()
model.add(Dense(units=32, activation='relu', input_shape=(6,)))
model.add(Dense(units=16, activation='relu'))
model.add(Dense(units=6, activation='sigmoid'))
model.compile(optimizer='adam', loss='mse')
model.summary()
# Out:
# Model: "sequential_12"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_36 (Dense)            (None, 32)                224
#
#  dense_37 (Dense)            (None, 16)                528
#
#  dense_38 (Dense)            (None, 6)                 102
#
# =================================================================
# Total params: 854
# Trainable params: 854
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(x=X_train, y=y_train, epochs = 50, verbose =1)
# Out:
# Epoch 1/50
# 55/55 [==============================] - 1s 3ms/step - loss: 0.0754
# Epoch 2/50
# 55/55 [==============================] - 0s 3ms/step - loss: 0.0593
# Epoch 3/50
# 55/55 [==============================] - 0s 4ms/step - loss: 0.0539
# Epoch 4/50
# 55/55 [==============================] - 0s 3ms/step - loss: 0.0503
# Epoch 5/50
# 55/55 [==============================] - 0s 3ms/step - loss: 0.0478
# Epoch 6/50
# 55/55 [==============================] - 0s 3ms/step - loss: 0.0464
# Epoch 7/50
# 55/55 [==============================] - 0s 3ms/step - loss: 0.0456
# Epoch 8/50
# 55/55 [==============================] - 0s 3ms/step - loss: 0.0446
# Epoch 9/50
# 55/55 [==============================] - 0s 3ms/step - loss: 0.0439
# Epoch 10/50
# 55/55 [==============================] - 0s 3ms/step - loss: 0.0430
# Epoch 11/50
# 55/55 [==============================] - 0s 3ms/step - loss: 0.0424
# Epoch 12/50
# 55/55 [==============================] - 0s 3ms/step - loss: 0.0420
# Epoch 13/50
# 55/55 [==============================] - 0s 3ms/step - loss: 0.0414
# Epoch 14/50
# 55/55 [==============================] - 0s 3ms/step - loss: 0.0411
# Epoch 15/50
# 55/55 [==============================] - 0s 3ms/step - loss: 0.0411
# Epoch 16/50
# 55/55 [==============================] - 0s 3ms/step - loss: 0.0408
# Epoch 17/50
# 55/55 [==============================] - 0s 3ms/step - loss: 0.0406
# Epoch 18/50
# 55/55 [==============================] - 0s 3ms/step - loss: 0.0403
# Epoch 19/50
# 55/55 [==============================] - 0s 3ms/step - loss: 0.0403
# Epoch 20/50
# 55/55 [==============================] - 0s 3ms/step - loss: 0.0406
# Epoch 21/50
# 55/55 [==============================] - 0s 3ms/step - loss: 0.0402
# Epoch 22/50
# 55/55 [==============================] - 0s 3ms/step - loss: 0.0405
# Epoch 23/50
# 55/55 [==============================] - 0s 3ms/step - loss: 0.0400
# Epoch 24/50
# 55/55 [==============================] - 0s 3ms/step - loss: 0.0398
# Epoch 25/50
# 55/55 [==============================] - 0s 3ms/step - loss: 0.0399
# Epoch 26/50
# 55/55 [==============================] - 0s 3ms/step - loss: 0.0399
# Epoch 27/50
# 55/55 [==============================] - 0s 3ms/step - loss: 0.0398
# Epoch 28/50
# 55/55 [==============================] - 0s 3ms/step - loss: 0.0398
# Epoch 29/50
# 55/55 [==============================] - 0s 3ms/step - loss: 0.0398
# Epoch 30/50
# 55/55 [==============================] - 0s 3ms/step - loss: 0.0396
# Epoch 31/50
# 55/55 [==============================] - 0s 3ms/step - loss: 0.0397
# Epoch 32/50
# 55/55 [==============================] - 0s 3ms/step - loss: 0.0397
# Epoch 33/50
# 55/55 [==============================] - 0s 3ms/step - loss: 0.0395
# Epoch 34/50
# 55/55 [==============================] - 0s 3ms/step - loss: 0.0396
# Epoch 35/50
# 55/55 [==============================] - 0s 3ms/step - loss: 0.0397
# Epoch 36/50
# 55/55 [==============================] - 0s 3ms/step - loss: 0.0396
# Epoch 37/50
# 55/55 [==============================] - 0s 3ms/step - loss: 0.0395
# Epoch 38/50
# 55/55 [==============================] - 0s 3ms/step - loss: 0.0395
# Epoch 39/50
# 55/55 [==============================] - 0s 3ms/step - loss: 0.0396
# Epoch 40/50
# 55/55 [==============================] - 0s 3ms/step - loss: 0.0394
# Epoch 41/50
# 55/55 [==============================] - 0s 3ms/step - loss: 0.0394
# Epoch 42/50
# 55/55 [==============================] - 0s 3ms/step - loss: 0.0394
# Epoch 43/50
# 55/55 [==============================] - 0s 3ms/step - loss: 0.0395
# Epoch 44/50
# 55/55 [==============================] - 0s 3ms/step - loss: 0.0394
# Epoch 45/50
# 55/55 [==============================] - 0s 3ms/step - loss: 0.0395
# Epoch 46/50
# 55/55 [==============================] - 0s 3ms/step - loss: 0.0395
# Epoch 47/50
# 55/55 [==============================] - 0s 3ms/step - loss: 0.0394
# Epoch 48/50
# 55/55 [==============================] - 0s 3ms/step - loss: 0.0394
# Epoch 49/50
# 55/55 [==============================] - 0s 3ms/step - loss: 0.0395
# Epoch 50/50
# 55/55 [==============================] - 0s 3ms/step - loss: 0.0393

# %%
plt.plot(model.history.history['loss'])

# %% [markdown]
# # Test

# %%
y_predict = model.predict(X_test)
y_predict = y_predict


y_predict = scaler.inverse_transform(y_predict)
y_real = scaler.inverse_transform(y_test)


Ttb_pred, Tx_pred, Tn_pred, R_pred, Utb_pred, Un_pred = y_predict[:,0], y_predict[:,1], y_predict[:,2], y_predict[:,3], y_predict[:,4], y_predict[:,5]

Ttb_real, Tx_real, Tn_real, R_real, Utb_real, Un_real = y_real[:,0], y_real[:,1], y_real[:,2], y_real[:,3], y_real[:,4], y_real[:,5]

print(np.shape(Ttb_pred), np.shape(Tn_real))
# Out:
# 14/14 [==============================] - 0s 2ms/step
# (439,) (439,)

# %%
np.shape(y_predict)
# Out:
# (439, 6)

# %% [markdown]
# # Evaluating

# %% [markdown]
# ### Ttb (Mean Temperature)

# %%
Ttb_MAE = np.array(tf.keras.metrics.mean_squared_error(Ttb_real, Ttb_pred))
Ttb_MAE
# Out:
# array(2.7490404, dtype=float32)

# %%
#Visualizing
plt.figure(figsize=(19,6))
plt.plot(dataset[pos_split+1:].index, Ttb_real, c='red', label='real')
plt.plot(dataset[pos_split+1:].index, Ttb_pred, c='green', label='predict')
plt.legend()
plt.ylabel('Mean Temperature');

# %% [markdown]
# ### Tx (Max Temperature)

# %%
Tx_MAE = np.array(tf.keras.metrics.mean_squared_error(Tx_real, Tx_pred))
Tx_MAE
# Out:
# array(5.3111897, dtype=float32)

# %%
plt.figure(figsize=(19,6))
plt.plot(dataset[pos_split+1:].index, Tx_real, c='red', label='real')
plt.plot(dataset[pos_split+1:].index, Tx_pred, c='green', label='predict')
plt.legend()
plt.ylabel('Max Temperature');

# %% [markdown]
# ### Tn (Min Temperature)

# %%
Tn_MAE = np.array(tf.keras.metrics.mean_squared_error(Tn_real, Tn_pred))
Tn_MAE
# Out:
# array(3.36328, dtype=float32)

# %%
plt.figure(figsize=(19,6))
plt.plot(dataset[pos_split+1:].index, Tn_real, c='red', label='real')
plt.plot(dataset[pos_split+1:].index, Tn_pred, c='green', label='predict')
plt.legend()
plt.ylabel('Min Temperature');

# %% [markdown]
# ### R (Rain)

# %%
#for i in range(len(R_pred)):
#    if R_pred[i] < 0.5:
#        R_pred[i] = 0
#    else:
#        R_pred[i] = 1
        
#np.shape(R)

# %%
BA = tf.keras.metrics.BinaryAccuracy(threshold=0.5)
BA.update_state(R_real, R_pred)
R_Accuracy = BA.result().numpy()
R_Accuracy
# Out:
# 0.7312073

# %% [markdown]
# ### Utb (Mean Humidity)

# %%
Utb_MAE = np.array(tf.keras.metrics.mean_squared_error(Utb_real, Utb_pred))
Utb_MAE
# Out:
# array(34.898697, dtype=float32)

# %%
plt.figure(figsize=(19,6))
plt.plot(dataset[pos_split+1:].index, Utb_real, c='red', label='real')
plt.plot(dataset[pos_split+1:].index, Utb_pred, c='green', label='predict')
plt.legend()
plt.ylabel('Mean Humidity');

# %% [markdown]
# ### Un (Min Humidity)

# %%
Un_MAE = np.array(tf.keras.metrics.mean_squared_error(Un_real, Un_pred))
Un_MAE
# Out:
# array(106.96858, dtype=float32)

# %%
plt.figure(figsize=(19,6))
plt.plot(dataset[pos_split+1:].index, Un_real, c='red', label='real')
plt.plot(dataset[pos_split+1:].index, Un_pred, c='green', label='predict')
plt.legend()
plt.ylabel('Min Humidity');

# %% [markdown]
# ## Conclusion

# %%
result = pd.DataFrame({
    'Predict' : ['Ttb (Nhiệt độ trung bình)', 'Tx (Nhiệt độ cao nhất)', 'Tn (Nhiệt độ thấp nhất)', 'Utb (Độ ẩm trung bình)', 'Un (Độ ẩm thấp nhất)'],
    'MAE' : [Ttb_MAE, Tx_MAE, Tn_MAE, Utb_MAE, Un_MAE]
})

result = result.sort_values(by='MAE', ascending=False)
result = result.set_index('Predict')
result
# Out:
#                                  MAE
# Predict
# Un (Độ ẩm thấp nhất)       106.96858
# Utb (Độ ẩm trung bình)     34.898697
# Tx (Nhiệt độ cao nhất)     5.3111897
# Tn (Nhiệt độ thấp nhất)      3.36328
# Ttb (Nhiệt độ trung bình)  2.7490404

# %%
print(f'Độ chính xác khi dự đoán có mưa hay không {R_Accuracy}')
# Out:
# Độ chính xác khi dự đoán có mưa hay không 0.7312073111534119
